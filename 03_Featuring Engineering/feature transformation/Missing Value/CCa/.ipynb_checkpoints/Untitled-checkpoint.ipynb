# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('data_science_job.csv')

# %%
value=df.isnull().mean()*100

# %%
### we will remove thosse rows which have mising values <5%

# %%
cols = [col for col in df.columns if df[col].isnull().mean() > 0.0 and df[col].isnull().mean() < 0.05]
cols
# Out:
# ['city_development_index',
#  'enrolled_university',
#  'education_level',
#  'experience',
#  'training_hours']

# %%
newdf=df[cols].dropna()
newdf
# Out:
#        city_development_index enrolled_university education_level  experience  \
# 0                       0.920       no_enrollment        Graduate        20.0
# 1                       0.776       no_enrollment        Graduate        15.0
# 2                       0.624    Full time course        Graduate         5.0
# 4                       0.767       no_enrollment         Masters        20.0
# 5                       0.764    Part time course        Graduate        11.0
# ...                       ...                 ...             ...         ...
# 19153                   0.878       no_enrollment        Graduate        14.0
# 19154                   0.920       no_enrollment        Graduate        14.0
# 19155                   0.920       no_enrollment        Graduate        20.0
# 19156                   0.802       no_enrollment     High School         0.0
# 19157                   0.855       no_enrollment  Primary School         2.0
#
#        training_hours
# ...

# %%
#checking how much rows are droped
len(newdf)/len(df)
# Out:
# 0.8968577095730244

# %% [markdown]
# ## checking for graphs is comprable or not for NUmerical Data ##

# %%
import seaborn as sns

# %%
sns.kdeplot(df['city_development_index'])
sns.kdeplot(newdf['city_development_index'])
###both kde is overlapping so data distrubution before and after is not comparable and good for model
# Out:
# <Axes: xlabel='city_development_index', ylabel='Density'>

# %%
sns.kdeplot(df['experience'])
sns.kdeplot(newdf['experience'])
# Out:
# <Axes: xlabel='experience', ylabel='Density'>

# %%
sns.kdeplot(df['training_hours'])
sns.kdeplot(newdf['training_hours'])
# Out:
# <Axes: xlabel='training_hours', ylabel='Density'>

# %% [markdown]
# ## Checking ratio for catgorical data

# %%
def ratio(colname):
    before=[]
    after=[]
    for i in df[f'{colname}'].value_counts():
        before.append(i/len(df))
    for i in newdf[f'{colname}'].value_counts():
        after.append(i/len(newdf))
    print(pd.DataFrame(np.column_stack((before,after)),columns=[' before','after'],index=[df[f'{colname}'].value_counts().index]))

# %%
ratio('enrolled_university')
# Out:
#                        before     after
# enrolled_university
# no_enrollment        0.721213  0.735188
# Full time course     0.196106  0.200733
# Part time course     0.062533  0.064079

# %%
ratio('education_level')
# Out:
#                    before     after
# education_level
# Graduate         0.605387  0.619835
# Masters          0.227633  0.234082
# High School      0.105282  0.107380
# Phd              0.021610  0.022116
# Primary School   0.016077  0.016587

# %% [raw]
# #ratio is alsmost same
