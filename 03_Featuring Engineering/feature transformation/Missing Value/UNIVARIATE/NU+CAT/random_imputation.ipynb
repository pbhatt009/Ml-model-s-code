# %%
    import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('titanic_toy.csv')
df.head()
# Out:
#     Age     Fare  Family  Survived
# 0  22.0   7.2500       1         0
# 1  38.0  71.2833       1         1
# 2  26.0   7.9250       0         1
# 3  35.0  53.1000       1         1
# 4  35.0   8.0500       0         0

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(df.drop('Survived',axis=1),df['Survived'],test_size=0.2,random_state=42)

# %%
xtrain.isna().sum()
# Out:
# Age       140
# Fare       36
# Family      0
# dtype: int64

# %%
xtrain_fill=xtrain.copy()

# %%
values=(xtrain_fill['Age'].dropna().values)
index=xtrain_fill['Age'].index
for i in index:
    if pd.isnull(xtrain_fill['Age'][i]):
        xtrain_fill['Age'][i]=np.random.choice(values)

# %%
fvalues=(xtrain_fill['Fare'].dropna().values)
findex=xtrain_fill['Fare'].index
for i in findex:
    if pd.isnull(xtrain_fill['Fare'][i]):
        xtrain_fill['Fare'][i]=np.random.choice(fvalues)

# %%
xtrain_fill.isnull().sum()
# Out:
# Age       0
# Fare      0
# Family    0
# dtype: int64

# %%
def plot(col):

    sns.kdeplot(xtrain[f'{col}'],label='before')

    plt.legend()


    sns.kdeplot(xtrain_fill[f'{col}'],label='after')
    plt.title(f'{col}')
    plt.legend()

# %%
plot('Age')

# %%
plot('Fare')

# %%
xtrain['Age'].var()
# Out:
# 210.2517072477438

# %%
xtrain_fill['Age'].var()
# Out:
# 204.13799022661553
