# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('placement.csv')
df.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
sns.kdeplot(df['cgpa'])
# Out:
# <Axes: xlabel='cgpa', ylabel='Density'>

# %%
sns.kdeplot(df['placement_exam_marks'])
####skewed data we will use box  plot here
# Out:
# <Axes: xlabel='placement_exam_marks', ylabel='Density'>

# %%
sns.boxplot(df['placement_exam_marks'])
# Out:
# <Axes: ylabel='placement_exam_marks'>

# %% [markdown]
# df['placement_exam_marks'].describe()

# %%
iqr=44-17
q1=17
q3=44
min=q1-1.5*iqr
max=q3+1.5*iqr
max
# Out:
# 84.5

# %%
outlire=df[(df['placement_exam_marks']<min)|(df['placement_exam_marks']>max)]
outlire.shape
# Out:
# (15, 3)

# %% [markdown]
# ###   capping ###

# %%
### all outlires are  at upper side
updated_marks=pd.DataFrame(np.where((df['placement_exam_marks']<=max),df['placement_exam_marks'],max))
sns.boxplot(updated_marks)
# Out:
# <Axes: >

# %%
sns.kdeplot(updated_marks)
# Out:
# <Axes: ylabel='Density'>
