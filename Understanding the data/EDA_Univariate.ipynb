# %%
import pandas as pd
import seaborn as sns

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_csv('train_and_test2.csv')

# %%
df=df[['Passengerid','Age','Fare','Sex','Pclass','Embarked','2urvived']]
df=df.rename(columns={'2urvived':'Survived'})
n=df['Sex'].size;
for i in range(0,n):
    if(df['Sex'][i]==0):
        df['Sex'][i]="male"
    else:
        df['Sex'][i]="female"
df.sample(5)
# Out:
# C:\Users\bhatt\AppData\Local\Temp\ipykernel_41432\2938692848.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Sex'][i]="male"
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Passengerid  1309 non-null   int64
#  1   Age          1309 non-null   float64
#  2   Fare         1309 non-null   float64
#  3   Sex          1309 non-null   object
#  4   Pclass       1309 non-null   int64
#  5   Embarked     1307 non-null   float64
#  6   Survived     1309 non-null   int64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 71.7+ KB

# %% [markdown]
# **Analysis of Catogarical data**

# %% [markdown]
#  **a.Count plot**

# %%
sns.countplot(x='Survived', data=df)
df['Survived'].value_counts()
# Out:
# Survived
# 0    967
# 1    342
# Name: count, dtype: int64

# %%
 sns.countplot(x='Pclass', data=df)
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    709
# 1    323
# 2    277
# Name: count, dtype: int64

# %%
 sns.countplot(x='Sex', data=df)
df['Sex'].value_counts()
# Out:
# Sex
# male      843
# female    466
# Name: count, dtype: int64

# %% [markdown]
# **b.Pie chart**

# %%
df['Survived'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# **2.Analysis of numerical data**

# %% [markdown]
# **a.Histogrm**

# %%
import matplotlib.pyplot as plt

# %%
#used to show numerical data in catogarical bins
plt.hist(df['Age'],bins=20)
# Out:
# (array([ 51.,  21.,  22.,  40., 114., 160., 391., 122.,  97.,  64.,  51.,
#          57.,  38.,  27.,  21.,  20.,   5.,   5.,   2.,   1.]),
#  array([ 0.17  ,  4.1615,  8.153 , 12.1445, 16.136 , 20.1275, 24.119 ,
#         28.1105, 32.102 , 36.0935, 40.085 , 44.0765, 48.068 , 52.0595,
#         56.051 , 60.0425, 64.034 , 68.0255, 72.017 , 76.0085, 80.    ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# **b.distplot**

# %%
sns.displot(x='Age', data=df, kde=True, bins=30)
plt.show()

# %% [markdown]
# **c-Boxplot**

# %%
sns.boxplot(df['Fare'])\
# boxplot is useful for finding outlires
# Out:
# <Axes: ylabel='Fare'>
